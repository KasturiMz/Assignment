# %%
#Q1. Explain GET and POST methods.
'''
GET method is used to return data from the server.
POST method is used to send HTML form data to the server. The data received by the POST method is not cached by the server.
'''
# Out:
# '\nGET method is used to return data from the server.\nPOST method is used to send HTML form data to the server. The data received by the POST method is not cached by the server.\n'

# %%
#Q2. Why is request used in Flask?
'''
To access the incoming data in Flask, we have to use the request object.
'''
# Out:
# '\nTo access the incoming data in Flask, we have to use the request object.\n'

# %%
#Q3. Why is redirect() used in Flask?
'''
redirect() method is used for redirecting to other routes on the same application and external websites.
'''
# Out:
# '\nredirect() method is used for redirecting to other routes on the same application and external websites.\n'

# %%
#Q4. What are templates in Flask? Why is the render_template() function used?
'''
Templates are files that contain static data as well as placeholders for dynamic data.
render_template() function is used to render the external HTML file to be returned as the response from the view function.
'''
# Out:
# '\nTemplates are files that contain static data as well as placeholders for dynamic data.\nrender_template() function is used to render the external HTML file to be returned as the response from the view function.\n'

# %%
#Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![postman.png](attachment:451171f3-c0bb-4043-9414-ae9e006ec31b.png)
